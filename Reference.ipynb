# %%
import os
import shutil
import torch
import torch.nn as nn
import sys
import random
import numpy as np
from models.cifar_quant import cifar10_quantqf
import models.testset as ts
from models.train import *
import pickle

def dump_vars(filename, **vars):
    with open(filename, 'wb') as f:
        pickle.dump(vars, f)

if not os.path.exists('result'):
    os.makedirs('result')


cuda_device = 1
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)
torch.use_deterministic_algorithms(True)
torch.backends.cudnn.deterministic = True
torch.cuda.set_device(cuda_device)


lr = 4e-2
weight_decay = 1e-4
epochs = 300
best_prec = 0
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
result = {}
prec = {}

for k in [x for x in ts.Names if x != 'ORG']:
    model = cifar10_quantqf()
    model.cuda()
    criterion = nn.CrossEntropyLoss().cuda()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)
    result[k] = []
    prec[k] = []
    model_name = f'CIFAR10_{k}'
    fdir = f'result/{model_name}'
    if not os.path.exists(fdir):
        os.makedirs(fdir)
        
    best_prec = 0

    for epoch in range(0, epochs):
        adjust_learning_rate(optimizer, epoch)

        result[k].append(train(ts.train_ld_sets[k], model, criterion, optimizer, epoch))
        
        # evaluate on test set
        print("Validation starts")
        prec_cur = validate(ts.test_ld_sets[k], model, criterion)
        prec[k].append(prec_cur)

        # remember best precision and save checkpoint
        is_best = prec_cur > best_prec
        best_prec = max(prec_cur,best_prec)
        print('best acc: {:1f}'.format(best_prec))
        save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec': best_prec,
            'optimizer': optimizer.state_dict(),
        }, is_best, fdir)
    del model
# Out:
# Sequential(
#   (0): QuantConv2df(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (2): ReLU()
#   (3): QuantConv2df(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (5): ReLU()
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): QuantConv2df(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (9): ReLU()
#   (10): QuantConv2df(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (12): ReLU()
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (14): QuantConv2df(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (16): ReLU()
#   (17): QuantConv2df(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (19): ReLU()
#   (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (21): QuantConv2df(512, 1024, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (22): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (23): ReLU()
#   (24): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Sequential(
#   (0): Linear(in_features=1024, out_features=10, bias=True)
# )
# Epoch 0, Time 19.314, Loss 3.0236, Prec 23.330%
# Validation starts
# Time 0.22246670722961426, Loss 2.2173, Prec 28.340%
# best acc: 28.340000
# Epoch 1, Time 16.728, Loss 2.0249, Prec 34.910%
# Validation starts
# Time 0.2044527530670166, Loss 1.6352, Prec 41.880%
# best acc: 41.880000
# Epoch 2, Time 17.318, Loss 1.4863, Prec 46.530%
# Validation starts
# Time 0.1926288604736328, Loss 1.7207, Prec 43.000%
# best acc: 43.000000
# Epoch 3, Time 16.805, Loss 1.2773, Prec 54.388%
# Validation starts
# Time 0.20319271087646484, Loss 1.1743, Prec 58.070%
# best acc: 58.070000
# Epoch 4, Time 16.736, Loss 1.1327, Prec 59.736%
# Validation starts
# Time 0.21155428886413574, Loss 1.2058, Prec 58.030%
# best acc: 58.070000
# Epoch 5, Time 16.778, Loss 1.0289, Prec 63.744%
# Validation starts
# Time 0.19538354873657227, Loss 0.9951, Prec 64.640%
# best acc: 64.640000
# Epoch 6, Time 16.850, Loss 0.9311, Prec 67.312%
# Validation starts
# Time 0.17577672004699707, Loss 1.2324, Prec 59.430%
# best acc: 64.640000
# Epoch 7, Time 16.944, Loss 0.8607, Prec 69.808%
# Validation starts
# Time 0.19401907920837402, Loss 1.0337, Prec 65.410%
# best acc: 65.410000
# Epoch 8, Time 17.158, Loss 0.7987, Prec 72.062%
# Validation starts
# Time 0.18510890007019043, Loss 0.8997, Prec 69.930%
# best acc: 69.930000
# Epoch 9, Time 17.134, Loss 0.7603, Prec 73.584%
# Validation starts
# Time 0.21033811569213867, Loss 0.8567, Prec 71.720%
# best acc: 71.720000
# Epoch 10, Time 17.000, Loss 0.7116, Prec 75.090%
# Validation starts
# Time 0.20476436614990234, Loss 0.8370, Prec 72.300%
# best acc: 72.300000
# Epoch 11, Time 17.159, Loss 0.6833, Prec 76.480%
# Validation starts
# Time 0.2019503116607666, Loss 0.7830, Prec 74.110%
# best acc: 74.110000
# Epoch 12, Time 17.280, Loss 0.6585, Prec 76.908%
# Validation starts
# Time 0.21195363998413086, Loss 0.8039, Prec 73.290%
# best acc: 74.110000
# Epoch 13, Time 17.052, Loss 0.6186, Prec 78.414%
# Validation starts
# Time 0.20375871658325195, Loss 0.7413, Prec 75.770%
# best acc: 75.770000
# Epoch 14, Time 17.112, Loss 0.5952, Prec 79.282%
# Validation starts
# Time 0.17892813682556152, Loss 0.6478, Prec 78.300%
# best acc: 78.300000
# Epoch 15, Time 16.825, Loss 0.5738, Prec 79.876%
# Validation starts
# Time 0.1981954574584961, Loss 0.6595, Prec 78.520%
# best acc: 78.520000
# Epoch 16, Time 16.853, Loss 0.5491, Prec 80.744%
# Validation starts
# Time 0.19961857795715332, Loss 0.6876, Prec 77.790%
# best acc: 78.520000
# Epoch 17, Time 17.277, Loss 0.5303, Prec 81.314%
# Validation starts
# Time 0.19562220573425293, Loss 0.6619, Prec 78.250%
# best acc: 78.520000
# Epoch 18, Time 16.805, Loss 0.5052, Prec 82.512%
# Validation starts
# Time 0.17574858665466309, Loss 0.6986, Prec 77.980%
# best acc: 78.520000
# Epoch 19, Time 17.169, Loss 0.4992, Prec 82.636%
# Validation starts
# Time 0.20331120491027832, Loss 0.6785, Prec 78.450%
# best acc: 78.520000
# Epoch 20, Time 16.895, Loss 0.4839, Prec 83.156%
# Validation starts
# Time 0.1983177661895752, Loss 0.6769, Prec 79.060%
# best acc: 79.060000
# Epoch 21, Time 17.041, Loss 0.4693, Prec 83.566%
# Validation starts
# Time 0.19548583030700684, Loss 0.6346, Prec 79.470%
# best acc: 79.470000
# Epoch 22, Time 17.189, Loss 0.4548, Prec 84.044%
# Validation starts
# Time 0.20592141151428223, Loss 0.6476, Prec 79.450%
# best acc: 79.470000
# Epoch 23, Time 17.181, Loss 0.4354, Prec 84.816%
# Validation starts
# Time 0.21141338348388672, Loss 0.7148, Prec 78.160%
# best acc: 79.470000
# Epoch 24, Time 16.933, Loss 0.4157, Prec 85.424%
# Validation starts
# Time 0.1734175682067871, Loss 0.6747, Prec 79.380%
# best acc: 79.470000
# Epoch 25, Time 16.940, Loss 0.4052, Prec 85.832%
# Validation starts
# Time 0.19781732559204102, Loss 0.6408, Prec 80.220%
# best acc: 80.220000
# Epoch 26, Time 16.914, Loss 0.3903, Prec 86.252%
# Validation starts
# Time 0.20399904251098633, Loss 0.7211, Prec 78.770%
# best acc: 80.220000
# Epoch 27, Time 17.041, Loss 0.3887, Prec 86.418%
# Validation starts
# Time 0.20249605178833008, Loss 0.6737, Prec 79.580%
# best acc: 80.220000
# Epoch 28, Time 17.105, Loss 0.3773, Prec 86.878%
# Validation starts
# Time 0.17815256118774414, Loss 0.7235, Prec 78.900%
# best acc: 80.220000
# Epoch 29, Time 16.809, Loss 0.3511, Prec 87.508%
# Validation starts
# Time 0.20654916763305664, Loss 0.6847, Prec 80.000%
# best acc: 80.220000
# Epoch 30, Time 16.660, Loss 0.3485, Prec 87.736%
# Validation starts
# Time 0.17394042015075684, Loss 0.7195, Prec 80.110%
# best acc: 80.220000
# Epoch 31, Time 16.920, Loss 0.3495, Prec 87.912%
# Validation starts
# Time 0.19247817993164062, Loss 0.8420, Prec 77.380%
# best acc: 80.220000
# Epoch 32, Time 16.888, Loss 0.3346, Prec 88.234%
# Validation starts
# Time 0.1973743438720703, Loss 0.7061, Prec 79.770%
# best acc: 80.220000
# Epoch 33, Time 16.887, Loss 0.3240, Prec 88.710%
# Validation starts
# Time 0.19997024536132812, Loss 0.6996, Prec 80.580%
# best acc: 80.580000
# Epoch 34, Time 16.810, Loss 0.3211, Prec 88.866%
# Validation starts
# Time 0.20621705055236816, Loss 0.7359, Prec 79.970%
# best acc: 80.580000
# Epoch 35, Time 17.032, Loss 0.3092, Prec 89.152%
# Validation starts
# Time 0.2123420238494873, Loss 0.7895, Prec 79.400%
# best acc: 80.580000
# Epoch 36, Time 16.707, Loss 0.2969, Prec 89.560%
# Validation starts
# Time 0.19405388832092285, Loss 0.6582, Prec 81.330%
# best acc: 81.330000
# Epoch 37, Time 16.999, Loss 0.2852, Prec 90.060%
# Validation starts
# Time 0.20181703567504883, Loss 0.8425, Prec 78.410%
# best acc: 81.330000
# Epoch 38, Time 17.058, Loss 0.2887, Prec 90.020%
# Validation starts
# Time 0.20131659507751465, Loss 0.7820, Prec 79.360%
# best acc: 81.330000
# Epoch 39, Time 17.121, Loss 0.2750, Prec 90.322%
# Validation starts
# Time 0.1980273723602295, Loss 0.7803, Prec 80.070%
# best acc: 81.330000
# Epoch 40, Time 16.663, Loss 0.2733, Prec 90.410%
# Validation starts
# Time 0.1947946548461914, Loss 0.7594, Prec 79.880%
# best acc: 81.330000
# Epoch 41, Time 16.833, Loss 0.2631, Prec 90.804%
# Validation starts
# Time 0.2057485580444336, Loss 0.6885, Prec 81.270%
# best acc: 81.330000
# Epoch 42, Time 16.793, Loss 0.2660, Prec 90.658%
# Validation starts
# Time 0.20719456672668457, Loss 0.8345, Prec 79.840%
# best acc: 81.330000
# Epoch 43, Time 17.006, Loss 0.2552, Prec 90.886%
# Validation starts
# Time 0.19991755485534668, Loss 0.7111, Prec 81.600%
# best acc: 81.600000
# Epoch 44, Time 16.680, Loss 0.2516, Prec 90.970%
# Validation starts
# Time 0.20555901527404785, Loss 0.7374, Prec 81.850%
# best acc: 81.850000
# Epoch 45, Time 16.676, Loss 0.2414, Prec 91.576%
# Validation starts
# Time 0.20044827461242676, Loss 0.8054, Prec 79.930%
# best acc: 81.850000
# Epoch 46, Time 16.751, Loss 0.2389, Prec 91.516%
# Validation starts
# Time 0.20049738883972168, Loss 0.8591, Prec 78.660%
# best acc: 81.850000
# Epoch 47, Time 16.719, Loss 0.2332, Prec 91.794%
# Validation starts
# Time 0.19678354263305664, Loss 0.8728, Prec 79.270%
# best acc: 81.850000
# Epoch 48, Time 16.448, Loss 0.2291, Prec 91.860%
# Validation starts
# Time 0.1960463523864746, Loss 0.6839, Prec 81.460%
# best acc: 81.850000
# Epoch 49, Time 16.801, Loss 0.2295, Prec 92.026%
# Validation starts
# Time 0.20076608657836914, Loss 0.7255, Prec 82.150%
# best acc: 82.150000
# Epoch 50, Time 16.534, Loss 0.2271, Prec 92.070%
# Validation starts
# Time 0.19502925872802734, Loss 0.7929, Prec 81.320%
# best acc: 82.150000
# Epoch 51, Time 16.791, Loss 0.2126, Prec 92.578%
# Validation starts
# Time 0.19473767280578613, Loss 0.7297, Prec 81.980%
# best acc: 82.150000
# Epoch 52, Time 16.744, Loss 0.2076, Prec 92.712%
# Validation starts
# Time 0.19340753555297852, Loss 0.7301, Prec 82.250%
# best acc: 82.250000
# Epoch 53, Time 16.577, Loss 0.2077, Prec 92.598%
# Validation starts
# Time 0.19423770904541016, Loss 0.7454, Prec 81.740%
# best acc: 82.250000
# Epoch 54, Time 16.575, Loss 0.1996, Prec 92.966%
# Validation starts
# Time 0.1929640769958496, Loss 0.7809, Prec 82.600%
# best acc: 82.600000
# Epoch 55, Time 16.770, Loss 0.2142, Prec 92.626%
# Validation starts
# Time 0.19769787788391113, Loss 0.8034, Prec 81.920%
# best acc: 82.600000
# Epoch 56, Time 16.686, Loss 0.1918, Prec 93.314%
# Validation starts
# Time 0.19764232635498047, Loss 0.7379, Prec 81.830%
# best acc: 82.600000
# Epoch 57, Time 16.732, Loss 0.1927, Prec 93.134%
# Validation starts
# Time 0.19509482383728027, Loss 0.8577, Prec 80.400%
# best acc: 82.600000
# Epoch 58, Time 16.724, Loss 0.2004, Prec 92.986%
# Validation starts
# Time 0.1962287425994873, Loss 0.7795, Prec 82.460%
# best acc: 82.600000
# Epoch 59, Time 16.813, Loss 0.1860, Prec 93.480%
# Validation starts
# Time 0.18916964530944824, Loss 0.9973, Prec 78.160%
# best acc: 82.600000
# Epoch 60, Time 17.070, Loss 0.1917, Prec 93.324%
# Validation starts
# Time 0.19522976875305176, Loss 0.7785, Prec 81.670%
# best acc: 82.600000
# Epoch 61, Time 16.761, Loss 0.1903, Prec 93.388%
# Validation starts
# Time 0.1970386505126953, Loss 0.8652, Prec 81.890%
# best acc: 82.600000
# Epoch 62, Time 16.874, Loss 0.1751, Prec 93.752%
# Validation starts
# Time 0.2004256248474121, Loss 0.9262, Prec 81.020%
# best acc: 82.600000
# Epoch 63, Time 16.636, Loss 0.1835, Prec 93.544%
# Validation starts
# Time 0.1903696060180664, Loss 0.9092, Prec 80.430%
# best acc: 82.600000
# Epoch 64, Time 16.555, Loss 0.1703, Prec 94.080%
# Validation starts
# Time 0.19602465629577637, Loss 0.7958, Prec 82.740%
# best acc: 82.740000
# Epoch 65, Time 16.638, Loss 0.1722, Prec 94.102%
# Validation starts
# Time 0.19924640655517578, Loss 0.7599, Prec 82.710%
# best acc: 82.740000
# Epoch 66, Time 16.695, Loss 0.1628, Prec 94.248%
# Validation starts
# Time 0.1940290927886963, Loss 0.7402, Prec 82.730%
# best acc: 82.740000
# Epoch 67, Time 16.714, Loss 0.1619, Prec 94.284%
# Validation starts
# Time 0.20148587226867676, Loss 0.8186, Prec 82.400%
# best acc: 82.740000
# Epoch 68, Time 16.745, Loss 0.1580, Prec 94.392%
# Validation starts
# Time 0.19553160667419434, Loss 0.8116, Prec 82.450%
# best acc: 82.740000
# Epoch 69, Time 16.896, Loss 0.1558, Prec 94.468%
# Validation starts
# Time 0.19349122047424316, Loss 0.8349, Prec 82.090%
# best acc: 82.740000
# Epoch 70, Time 16.810, Loss 0.1716, Prec 94.094%
# Validation starts
# Time 0.19564127922058105, Loss 0.8537, Prec 81.130%
# best acc: 82.740000
# Epoch 71, Time 16.641, Loss 0.1658, Prec 94.226%
# Validation starts
# Time 0.19331693649291992, Loss 0.8397, Prec 80.850%
# best acc: 82.740000
# Epoch 72, Time 16.870, Loss 0.1538, Prec 94.738%
# Validation starts
# Time 0.2051703929901123, Loss 0.8856, Prec 81.760%
# best acc: 82.740000
# Epoch 73, Time 16.537, Loss 0.1512, Prec 94.684%
# Validation starts
# Time 0.19433975219726562, Loss 0.9810, Prec 80.760%
# best acc: 82.740000
# Epoch 74, Time 16.627, Loss 0.1429, Prec 95.088%
# Validation starts
# Time 0.1968073844909668, Loss 0.9358, Prec 81.230%
# best acc: 82.740000
# Epoch 75, Time 16.530, Loss 0.1422, Prec 95.068%
# Validation starts
# Time 0.1965644359588623, Loss 0.8917, Prec 81.630%
# best acc: 82.740000
# Epoch 76, Time 16.720, Loss 0.1455, Prec 94.918%
# Validation starts
# Time 0.1930382251739502, Loss 0.8506, Prec 82.420%
# best acc: 82.740000
# Epoch 77, Time 16.623, Loss 0.1388, Prec 95.210%
# Validation starts
# Time 0.20274949073791504, Loss 1.1387, Prec 79.120%
# best acc: 82.740000
# Epoch 78, Time 16.602, Loss 0.1519, Prec 94.690%
# Validation starts
# Time 0.20774078369140625, Loss 0.8349, Prec 82.600%
# best acc: 82.740000
# Epoch 79, Time 16.684, Loss 0.1457, Prec 94.920%
# Validation starts
# Time 0.20319056510925293, Loss 0.8187, Prec 82.830%
# best acc: 82.830000
# Epoch 80, Time 16.504, Loss 0.1468, Prec 94.904%
# Validation starts
# Time 0.20528173446655273, Loss 0.8268, Prec 82.700%
# best acc: 82.830000
# Epoch 81, Time 16.758, Loss 0.1351, Prec 95.322%
# Validation starts
# Time 0.20792222023010254, Loss 0.9442, Prec 81.550%
# best acc: 82.830000
# Epoch 82, Time 16.872, Loss 0.1370, Prec 95.216%
# Validation starts
# Time 0.1793534755706787, Loss 0.8233, Prec 82.350%
# best acc: 82.830000
# Epoch 83, Time 16.712, Loss 0.1425, Prec 95.042%
# Validation starts
# Time 0.19930195808410645, Loss 0.8849, Prec 81.440%
# best acc: 82.830000
# Epoch 84, Time 16.813, Loss 0.1315, Prec 95.478%
# Validation starts
# Time 0.2053842544555664, Loss 0.8448, Prec 82.500%
# best acc: 82.830000
# Epoch 85, Time 16.702, Loss 0.1265, Prec 95.568%
# Validation starts
# Time 0.20430469512939453, Loss 1.0543, Prec 80.820%
# best acc: 82.830000
# Epoch 86, Time 16.876, Loss 0.1335, Prec 95.270%
# Validation starts
# Time 0.20182180404663086, Loss 0.8695, Prec 82.550%
# best acc: 82.830000
# Epoch 87, Time 16.867, Loss 0.1350, Prec 95.292%
# Validation starts
# Time 0.1925828456878662, Loss 0.8677, Prec 82.440%
# best acc: 82.830000
# Epoch 88, Time 16.915, Loss 0.1225, Prec 95.716%
# Validation starts
# Time 0.19492483139038086, Loss 0.9944, Prec 81.290%
# best acc: 82.830000
# Epoch 89, Time 16.700, Loss 0.1316, Prec 95.470%
# Validation starts
# Time 0.1995711326599121, Loss 0.9429, Prec 81.650%
# best acc: 82.830000
# Epoch 90, Time 16.500, Loss 0.1192, Prec 95.872%
# Validation starts
# Time 0.20935845375061035, Loss 1.0258, Prec 80.550%
# best acc: 82.830000
# Epoch 91, Time 16.848, Loss 0.1288, Prec 95.566%
# Validation starts
# Time 0.20744562149047852, Loss 1.0500, Prec 80.470%
# best acc: 82.830000
# Epoch 92, Time 16.834, Loss 0.1261, Prec 95.560%
# Validation starts
# Time 0.20794367790222168, Loss 0.9415, Prec 82.220%
# best acc: 82.830000
# Epoch 93, Time 16.498, Loss 0.1235, Prec 95.718%
# Validation starts
# Time 0.19419217109680176, Loss 0.9366, Prec 81.970%
# best acc: 82.830000
# Epoch 94, Time 16.513, Loss 0.1243, Prec 95.790%
# Validation starts
# Time 0.19253826141357422, Loss 0.9401, Prec 81.480%
# best acc: 82.830000
# Epoch 95, Time 16.858, Loss 0.1157, Prec 95.950%
# Validation starts
# Time 0.19483709335327148, Loss 0.9002, Prec 82.090%
# best acc: 82.830000
# Epoch 96, Time 16.986, Loss 0.1307, Prec 95.590%
# Validation starts
# Time 0.20311880111694336, Loss 0.9342, Prec 81.160%
# best acc: 82.830000
# Epoch 97, Time 16.751, Loss 0.1305, Prec 95.550%
# Validation starts
# Time 0.19668865203857422, Loss 0.9769, Prec 81.420%
# best acc: 82.830000
# Epoch 98, Time 16.695, Loss 0.1144, Prec 95.998%
# Validation starts
# Time 0.19202113151550293, Loss 0.8031, Prec 83.180%
# best acc: 83.180000
# Epoch 99, Time 16.648, Loss 0.1155, Prec 96.028%
# Validation starts
# Time 0.19255614280700684, Loss 0.8282, Prec 83.810%
# best acc: 83.810000
# Epoch 100, Time 16.765, Loss 0.1238, Prec 95.710%
# Validation starts
# Time 0.23964595794677734, Loss 0.9181, Prec 82.160%
# best acc: 83.810000
# Epoch 101, Time 17.076, Loss 0.1170, Prec 95.890%
# Validation starts
# Time 0.19858312606811523, Loss 0.8722, Prec 82.610%
# best acc: 83.810000
# Epoch 102, Time 17.057, Loss 0.1222, Prec 95.872%
# Validation starts
# Time 0.20453095436096191, Loss 0.8337, Prec 82.690%
# best acc: 83.810000
# Epoch 103, Time 16.892, Loss 0.1217, Prec 95.768%
# Validation starts
# Time 0.197767972946167, Loss 0.8440, Prec 82.640%
# best acc: 83.810000
# Epoch 104, Time 16.957, Loss 0.1155, Prec 96.092%
# Validation starts
# Time 0.1998748779296875, Loss 0.8488, Prec 82.620%
# best acc: 83.810000
# Epoch 105, Time 16.978, Loss 0.1253, Prec 95.672%
# Validation starts
# Time 0.17790842056274414, Loss 0.8104, Prec 83.110%
# best acc: 83.810000
# Epoch 106, Time 17.141, Loss 0.1151, Prec 96.006%
# Validation starts
# Time 0.17149114608764648, Loss 0.9610, Prec 81.650%
# best acc: 83.810000
# Epoch 107, Time 16.955, Loss 0.1123, Prec 96.104%
# Validation starts
# Time 0.1799314022064209, Loss 1.0019, Prec 81.710%
# best acc: 83.810000
# Epoch 108, Time 16.785, Loss 0.1154, Prec 95.942%
# Validation starts
# Time 0.19294476509094238, Loss 0.8679, Prec 83.100%
# best acc: 83.810000
# Epoch 109, Time 17.068, Loss 0.1107, Prec 96.168%
# Validation starts
# Time 0.20102429389953613, Loss 0.9885, Prec 81.540%
# best acc: 83.810000
# Epoch 110, Time 17.067, Loss 0.1162, Prec 95.980%
# Validation starts
# Time 0.19551753997802734, Loss 0.8792, Prec 82.690%
# best acc: 83.810000
# Epoch 111, Time 16.887, Loss 0.1059, Prec 96.326%
# Validation starts
# Time 0.2061467170715332, Loss 0.8512, Prec 82.970%
# best acc: 83.810000
# Epoch 112, Time 16.854, Loss 0.1203, Prec 95.860%
# Validation starts
# Time 0.207322359085083, Loss 0.9700, Prec 81.700%
# best acc: 83.810000
# Epoch 113, Time 17.058, Loss 0.1169, Prec 95.956%
# Validation starts
# Time 0.18587565422058105, Loss 0.8159, Prec 83.240%
# best acc: 83.810000
# Epoch 114, Time 16.729, Loss 0.1160, Prec 95.990%
# Validation starts
# Time 0.200974702835083, Loss 0.9701, Prec 82.120%
# best acc: 83.810000
# Epoch 115, Time 17.108, Loss 0.1122, Prec 96.178%
# Validation starts
# Time 0.19005155563354492, Loss 0.9685, Prec 80.780%
# best acc: 83.810000
# Epoch 116, Time 16.979, Loss 0.1091, Prec 96.250%
# Validation starts
# Time 0.1996629238128662, Loss 0.8830, Prec 83.010%
# best acc: 83.810000
# Epoch 117, Time 16.579, Loss 0.1129, Prec 96.008%
# Validation starts
# Time 0.20225262641906738, Loss 0.9102, Prec 82.220%
# best acc: 83.810000
# Epoch 118, Time 16.818, Loss 0.1059, Prec 96.400%
# Validation starts
# Time 0.19781899452209473, Loss 0.9443, Prec 82.440%
# best acc: 83.810000
# Epoch 119, Time 16.983, Loss 0.1163, Prec 96.120%
# Validation starts
# Time 0.19716334342956543, Loss 1.0146, Prec 80.630%
# best acc: 83.810000
# Epoch 120, Time 17.045, Loss 0.1091, Prec 96.238%
# Validation starts
# Time 0.19790267944335938, Loss 0.8422, Prec 82.750%
# best acc: 83.810000
# Epoch 121, Time 16.643, Loss 0.1000, Prec 96.658%
# Validation starts
# Time 0.1985929012298584, Loss 0.8815, Prec 83.080%
# best acc: 83.810000
# Epoch 122, Time 17.291, Loss 0.1007, Prec 96.518%
# Validation starts
# Time 0.1998307704925537, Loss 1.0029, Prec 82.290%
# best acc: 83.810000
# Epoch 123, Time 16.872, Loss 0.1002, Prec 96.508%
# Validation starts
# Time 0.21266818046569824, Loss 0.8659, Prec 82.080%
# best acc: 83.810000
# Epoch 124, Time 16.763, Loss 0.1093, Prec 96.172%
# Validation starts
# Time 0.20174217224121094, Loss 0.8752, Prec 83.120%
# best acc: 83.810000
# Epoch 125, Time 17.010, Loss 0.1098, Prec 96.174%
# Validation starts
# Time 0.1811671257019043, Loss 0.8818, Prec 83.310%
# best acc: 83.810000
# Epoch 126, Time 16.845, Loss 0.1205, Prec 96.026%
# Validation starts
# Time 0.198807954788208, Loss 0.8208, Prec 83.240%
# best acc: 83.810000
# Epoch 127, Time 16.868, Loss 0.1020, Prec 96.398%
# Validation starts
# Time 0.20555353164672852, Loss 0.8476, Prec 82.860%
# best acc: 83.810000
# Epoch 128, Time 16.940, Loss 0.1010, Prec 96.564%
# Validation starts
# Time 0.19326329231262207, Loss 1.0402, Prec 81.450%
# best acc: 83.810000
# Epoch 129, Time 17.317, Loss 0.1071, Prec 96.288%
# Validation starts
# Time 0.24194860458374023, Loss 0.9843, Prec 82.070%
# best acc: 83.810000
# Epoch 130, Time 17.703, Loss 0.1083, Prec 96.230%
# Validation starts
# Time 0.1992342472076416, Loss 1.1369, Prec 79.800%
# best acc: 83.810000
# Epoch 131, Time 16.724, Loss 0.1020, Prec 96.434%
# Validation starts
# Time 0.20458745956420898, Loss 0.9177, Prec 81.890%
# best acc: 83.810000
# Epoch 132, Time 16.457, Loss 0.0997, Prec 96.624%
# Validation starts
# Time 0.18160629272460938, Loss 0.8653, Prec 82.560%
# best acc: 83.810000
# Epoch 133, Time 16.762, Loss 0.1078, Prec 96.242%
# Validation starts
# Time 0.16761994361877441, Loss 0.8689, Prec 82.710%
# best acc: 83.810000
# Epoch 134, Time 16.753, Loss 0.1069, Prec 96.276%
# Validation starts
# Time 0.1721515655517578, Loss 0.9033, Prec 83.020%
# best acc: 83.810000
# Epoch 135, Time 17.108, Loss 0.1006, Prec 96.524%
# Validation starts
# Time 0.1998915672302246, Loss 0.9629, Prec 82.200%
# best acc: 83.810000
# Epoch 136, Time 17.639, Loss 0.1156, Prec 96.090%
# Validation starts
# Time 0.17597246170043945, Loss 0.9178, Prec 81.690%
# best acc: 83.810000
# Epoch 137, Time 16.737, Loss 0.1099, Prec 96.282%
# Validation starts
# Time 0.17768287658691406, Loss 0.9385, Prec 82.210%
# best acc: 83.810000
# Epoch 138, Time 16.762, Loss 0.1078, Prec 96.422%
# Validation starts
# Time 0.19864249229431152, Loss 0.9398, Prec 81.800%
# best acc: 83.810000
# Epoch 139, Time 16.692, Loss 0.0916, Prec 96.844%
# Validation starts
# Time 0.17952990531921387, Loss 0.8701, Prec 82.870%
# best acc: 83.810000
# Epoch 140, Time 17.375, Loss 0.0936, Prec 96.780%
# Validation starts
# Time 0.19848871231079102, Loss 0.8863, Prec 83.000%
# best acc: 83.810000
# Epoch 141, Time 16.707, Loss 0.0920, Prec 96.778%
# Validation starts
# Time 0.16623163223266602, Loss 0.9313, Prec 82.090%
# best acc: 83.810000
# Epoch 142, Time 16.666, Loss 0.1054, Prec 96.322%
# Validation starts
# Time 0.17102813720703125, Loss 0.8899, Prec 82.630%
# best acc: 83.810000
# Epoch 143, Time 16.782, Loss 0.1067, Prec 96.480%
# Validation starts
# Time 0.20697999000549316, Loss 0.8989, Prec 82.200%
# best acc: 83.810000
# Epoch 144, Time 16.898, Loss 0.1036, Prec 96.376%
# Validation starts
# Time 0.17525768280029297, Loss 0.9584, Prec 82.070%
# best acc: 83.810000
# Epoch 145, Time 16.951, Loss 0.1002, Prec 96.502%
# Validation starts
# Time 0.17494726181030273, Loss 0.9849, Prec 81.350%
# best acc: 83.810000
# Epoch 146, Time 16.895, Loss 0.1008, Prec 96.544%
# Validation starts
# Time 0.2009587287902832, Loss 0.9296, Prec 82.210%
# best acc: 83.810000
# Epoch 147, Time 16.864, Loss 0.1042, Prec 96.510%
# Validation starts
# Time 0.19057679176330566, Loss 0.8228, Prec 83.230%
# best acc: 83.810000
# Epoch 148, Time 16.776, Loss 0.0979, Prec 96.584%
# Validation starts
# Time 0.19112586975097656, Loss 0.8704, Prec 83.050%
# best acc: 83.810000
# Epoch 149, Time 16.746, Loss 0.0979, Prec 96.614%
# Validation starts
# Time 0.1760098934173584, Loss 0.9279, Prec 81.660%
# best acc: 83.810000
# Epoch 150, Time 16.907, Loss 0.0484, Prec 98.344%
# Validation starts
# Time 0.17435455322265625, Loss 0.6758, Prec 86.200%
# best acc: 86.200000
# Epoch 151, Time 16.793, Loss 0.0271, Prec 99.122%
# Validation starts
# Time 0.20453667640686035, Loss 0.6707, Prec 86.600%
# best acc: 86.600000
# Epoch 152, Time 16.814, Loss 0.0219, Prec 99.318%
# Validation starts
# Time 0.1785740852355957, Loss 0.6598, Prec 86.720%
# best acc: 86.720000
# Epoch 153, Time 16.961, Loss 0.0178, Prec 99.438%
# Validation starts
# Time 0.184098482131958, Loss 0.6700, Prec 86.550%
# best acc: 86.720000
# Epoch 154, Time 17.280, Loss 0.0166, Prec 99.530%
# Validation starts
# Time 0.2150590419769287, Loss 0.6647, Prec 86.580%
# best acc: 86.720000
# Epoch 155, Time 16.805, Loss 0.0146, Prec 99.572%
# Validation starts
# Time 0.19610190391540527, Loss 0.6641, Prec 86.840%
# best acc: 86.840000
# Epoch 156, Time 16.783, Loss 0.0126, Prec 99.644%
# Validation starts
# Time 0.20089292526245117, Loss 0.6679, Prec 86.610%
# best acc: 86.840000
# Epoch 157, Time 16.855, Loss 0.0127, Prec 99.638%
# Validation starts
# Time 0.19595551490783691, Loss 0.6784, Prec 86.690%
# best acc: 86.840000
# Epoch 158, Time 16.835, Loss 0.0124, Prec 99.640%
# Validation starts
# Time 0.19687604904174805, Loss 0.6708, Prec 86.910%
# best acc: 86.910000
# Epoch 159, Time 16.848, Loss 0.0114, Prec 99.682%
# Validation starts
# Time 0.19881248474121094, Loss 0.6770, Prec 86.830%
# best acc: 86.910000
# Epoch 160, Time 16.799, Loss 0.0107, Prec 99.700%
# Validation starts
# Time 0.193739652633667, Loss 0.6812, Prec 86.840%
# best acc: 86.910000
# Epoch 161, Time 16.762, Loss 0.0101, Prec 99.722%
# Validation starts
# Time 0.19647884368896484, Loss 0.6942, Prec 86.910%
# best acc: 86.910000
# Epoch 162, Time 16.669, Loss 0.0092, Prec 99.724%
# Validation starts
# Time 0.19901680946350098, Loss 0.6963, Prec 86.740%
# best acc: 86.910000
# Epoch 163, Time 16.829, Loss 0.0085, Prec 99.792%
# Validation starts
# Time 0.19522929191589355, Loss 0.6984, Prec 87.170%
# best acc: 87.170000
# Epoch 164, Time 16.741, Loss 0.0084, Prec 99.810%
# Validation starts
# Time 0.19982028007507324, Loss 0.6869, Prec 86.980%
# best acc: 87.170000
# Epoch 165, Time 16.835, Loss 0.0079, Prec 99.814%
# Validation starts
# Time 0.20328164100646973, Loss 0.6935, Prec 86.820%
# best acc: 87.170000
# Epoch 166, Time 16.777, Loss 0.0068, Prec 99.880%
# Validation starts
# Time 0.1929795742034912, Loss 0.6955, Prec 86.860%
# best acc: 87.170000
# Epoch 167, Time 16.675, Loss 0.0074, Prec 99.820%
# Validation starts
# Time 0.19505834579467773, Loss 0.6978, Prec 86.940%
# best acc: 87.170000
# Epoch 168, Time 16.842, Loss 0.0065, Prec 99.848%
# Validation starts
# Time 0.19390106201171875, Loss 0.7048, Prec 86.860%
# best acc: 87.170000
# Epoch 169, Time 16.993, Loss 0.0067, Prec 99.852%
# Validation starts
# Time 0.1966540813446045, Loss 0.7121, Prec 86.670%
# best acc: 87.170000
# Epoch 170, Time 16.918, Loss 0.0063, Prec 99.870%
# Validation starts
# Time 0.19609522819519043, Loss 0.7229, Prec 86.470%
# best acc: 87.170000
# Epoch 171, Time 16.705, Loss 0.0063, Prec 99.874%
# Validation starts
# Time 0.19834351539611816, Loss 0.7157, Prec 86.830%
# best acc: 87.170000
# Epoch 172, Time 16.567, Loss 0.0059, Prec 99.880%
# Validation starts
# Time 0.19672751426696777, Loss 0.7099, Prec 87.080%
# best acc: 87.170000
# Epoch 173, Time 16.854, Loss 0.0058, Prec 99.878%
# Validation starts
# Time 0.19417667388916016, Loss 0.7110, Prec 87.180%
# best acc: 87.180000
# Epoch 174, Time 16.752, Loss 0.0059, Prec 99.864%
# Validation starts
# Time 0.19747352600097656, Loss 0.7252, Prec 86.890%
# best acc: 87.180000
# Epoch 175, Time 16.702, Loss 0.0058, Prec 99.878%
# Validation starts
# Time 0.19721579551696777, Loss 0.7284, Prec 86.850%
# best acc: 87.180000
# Epoch 176, Time 16.701, Loss 0.0049, Prec 99.922%
# Validation starts
# Time 0.19803595542907715, Loss 0.7220, Prec 87.100%
# best acc: 87.180000
# Epoch 177, Time 16.642, Loss 0.0054, Prec 99.876%
# Validation starts
# Time 0.19779634475708008, Loss 0.7217, Prec 87.050%
# best acc: 87.180000
# Epoch 178, Time 16.782, Loss 0.0051, Prec 99.902%
# Validation starts
# Time 0.19781708717346191, Loss 0.7210, Prec 86.990%
# best acc: 87.180000
# Epoch 179, Time 16.638, Loss 0.0045, Prec 99.922%
# Validation starts
# Time 0.1955702304840088, Loss 0.7273, Prec 86.920%
# best acc: 87.180000
# Epoch 180, Time 16.955, Loss 0.0042, Prec 99.928%
# Validation starts
# Time 0.19579100608825684, Loss 0.7214, Prec 86.980%
# best acc: 87.180000
# Epoch 181, Time 16.485, Loss 0.0041, Prec 99.944%
# Validation starts
# Time 0.190720796585083, Loss 0.7189, Prec 87.090%
# best acc: 87.180000
# Epoch 182, Time 16.627, Loss 0.0043, Prec 99.912%
# Validation starts
# Time 0.19619250297546387, Loss 0.7318, Prec 86.850%
# best acc: 87.180000
# Epoch 183, Time 16.621, Loss 0.0045, Prec 99.910%
# Validation starts
# Time 0.2008652687072754, Loss 0.7376, Prec 86.950%
# best acc: 87.180000
# Epoch 184, Time 17.103, Loss 0.0042, Prec 99.932%
# Validation starts
# Time 0.2055203914642334, Loss 0.7358, Prec 86.860%
# best acc: 87.180000
# Epoch 185, Time 16.424, Loss 0.0043, Prec 99.908%
# Validation starts
# Time 0.19943571090698242, Loss 0.7417, Prec 86.900%
# best acc: 87.180000
# Epoch 186, Time 16.662, Loss 0.0037, Prec 99.942%
# Validation starts
# Time 0.21054649353027344, Loss 0.7348, Prec 86.840%
# best acc: 87.180000
# Epoch 187, Time 16.918, Loss 0.0036, Prec 99.950%
# Validation starts
# Time 0.2055816650390625, Loss 0.7348, Prec 86.800%
# best acc: 87.180000
# Epoch 188, Time 16.601, Loss 0.0034, Prec 99.950%
# Validation starts
# Time 0.2028045654296875, Loss 0.7376, Prec 86.980%
# best acc: 87.180000
# Epoch 189, Time 16.808, Loss 0.0035, Prec 99.946%
# Validation starts
# Time 0.19808506965637207, Loss 0.7422, Prec 87.040%
# best acc: 87.180000
# Epoch 190, Time 16.989, Loss 0.0036, Prec 99.932%
# Validation starts
# Time 0.20436882972717285, Loss 0.7406, Prec 87.010%
# best acc: 87.180000
# Epoch 191, Time 16.747, Loss 0.0036, Prec 99.940%
# Validation starts
# Time 0.20135498046875, Loss 0.7414, Prec 86.930%
# best acc: 87.180000
# Epoch 192, Time 16.944, Loss 0.0032, Prec 99.960%
# Validation starts
# Time 0.1954195499420166, Loss 0.7370, Prec 87.040%
# best acc: 87.180000
# Epoch 193, Time 16.631, Loss 0.0030, Prec 99.950%
# Validation starts
# Time 0.19711756706237793, Loss 0.7363, Prec 87.150%
# best acc: 87.180000
# Epoch 194, Time 16.746, Loss 0.0030, Prec 99.960%
# Validation starts
# Time 0.2414078712463379, Loss 0.7347, Prec 87.070%
# best acc: 87.180000
# Epoch 195, Time 16.672, Loss 0.0033, Prec 99.940%
# Validation starts
# Time 0.17923378944396973, Loss 0.7418, Prec 87.240%
# best acc: 87.240000
# Epoch 196, Time 16.803, Loss 0.0031, Prec 99.940%
# Validation starts
# Time 0.17020297050476074, Loss 0.7451, Prec 86.950%
# best acc: 87.240000
# Epoch 197, Time 16.958, Loss 0.0027, Prec 99.976%
# Validation starts
# Time 0.1959071159362793, Loss 0.7404, Prec 87.050%
# best acc: 87.240000
# Epoch 198, Time 17.226, Loss 0.0032, Prec 99.946%
# Validation starts
# Time 0.2122957706451416, Loss 0.7396, Prec 87.130%
# best acc: 87.240000
# Epoch 199, Time 17.040, Loss 0.0032, Prec 99.934%
# Validation starts
# Time 0.20144295692443848, Loss 0.7427, Prec 87.000%
# best acc: 87.240000
# Epoch 200, Time 16.915, Loss 0.0025, Prec 99.968%
# Validation starts
# Time 0.1698911190032959, Loss 0.7404, Prec 87.270%
# best acc: 87.270000
# Epoch 201, Time 16.988, Loss 0.0031, Prec 99.962%
# Validation starts
# Time 0.1749255657196045, Loss 0.7406, Prec 86.960%
# best acc: 87.270000
# Epoch 202, Time 17.047, Loss 0.0029, Prec 99.962%
# Validation starts
# Time 0.1783597469329834, Loss 0.7407, Prec 87.240%
# best acc: 87.270000
# Epoch 203, Time 16.939, Loss 0.0028, Prec 99.958%
# Validation starts
# Time 0.17346501350402832, Loss 0.7479, Prec 87.070%
# best acc: 87.270000
# Epoch 204, Time 16.667, Loss 0.0026, Prec 99.974%
# Validation starts
# Time 0.1696481704711914, Loss 0.7461, Prec 86.910%
# best acc: 87.270000
# Epoch 205, Time 16.986, Loss 0.0024, Prec 99.978%
# Validation starts
# Time 0.17379355430603027, Loss 0.7536, Prec 86.950%
# best acc: 87.270000
# Epoch 206, Time 16.849, Loss 0.0025, Prec 99.966%
# Validation starts
# Time 0.19951915740966797, Loss 0.7531, Prec 86.930%
# best acc: 87.270000
# Epoch 207, Time 16.751, Loss 0.0028, Prec 99.956%
# Validation starts
# Time 0.2009875774383545, Loss 0.7469, Prec 86.930%
# best acc: 87.270000
# Epoch 208, Time 16.824, Loss 0.0025, Prec 99.966%
# Validation starts
# Time 0.17172789573669434, Loss 0.7560, Prec 86.830%
# best acc: 87.270000
# Epoch 209, Time 17.020, Loss 0.0025, Prec 99.968%
# Validation starts
# Time 0.1732621192932129, Loss 0.7526, Prec 87.080%
# best acc: 87.270000
# Epoch 210, Time 17.416, Loss 0.0025, Prec 99.960%
# Validation starts
# Time 0.1696949005126953, Loss 0.7540, Prec 87.290%
# best acc: 87.290000
# Epoch 211, Time 17.398, Loss 0.0023, Prec 99.968%
# Validation starts
# Time 0.17040157318115234, Loss 0.7478, Prec 86.980%
# best acc: 87.290000
# Epoch 212, Time 16.766, Loss 0.0024, Prec 99.976%
# Validation starts
# Time 0.1987287998199463, Loss 0.7490, Prec 86.960%
# best acc: 87.290000
# Epoch 213, Time 16.635, Loss 0.0022, Prec 99.978%
# Validation starts
# Time 0.19498729705810547, Loss 0.7510, Prec 87.100%
# best acc: 87.290000
# Epoch 214, Time 16.903, Loss 0.0022, Prec 99.966%
# Validation starts
# Time 0.18108701705932617, Loss 0.7570, Prec 87.000%
# best acc: 87.290000
# Epoch 215, Time 16.754, Loss 0.0023, Prec 99.972%
# Validation starts
# Time 0.17510771751403809, Loss 0.7566, Prec 86.910%
# best acc: 87.290000
# Epoch 216, Time 16.985, Loss 0.0023, Prec 99.962%
# Validation starts
# Time 0.17540836334228516, Loss 0.7522, Prec 87.190%
# best acc: 87.290000
# Epoch 217, Time 17.044, Loss 0.0023, Prec 99.980%
# Validation starts
# Time 0.2051689624786377, Loss 0.7521, Prec 87.050%
# best acc: 87.290000
# Epoch 218, Time 17.045, Loss 0.0021, Prec 99.982%
# Validation starts
# Time 0.20144057273864746, Loss 0.7551, Prec 87.090%
# best acc: 87.290000
# Epoch 219, Time 16.667, Loss 0.0022, Prec 99.972%
# Validation starts
# Time 0.22022604942321777, Loss 0.7592, Prec 87.240%
# best acc: 87.290000
# Epoch 220, Time 16.789, Loss 0.0019, Prec 99.982%
# Validation starts
# Time 0.19773340225219727, Loss 0.7541, Prec 87.260%
# best acc: 87.290000
# Epoch 221, Time 16.586, Loss 0.0018, Prec 99.990%
# Validation starts
# Time 0.20114994049072266, Loss 0.7569, Prec 87.010%
# best acc: 87.290000
# Epoch 222, Time 17.367, Loss 0.0021, Prec 99.972%
# Validation starts
# Time 0.19902873039245605, Loss 0.7620, Prec 86.780%
# best acc: 87.290000
# Epoch 223, Time 16.690, Loss 0.0020, Prec 99.976%
# Validation starts
# Time 0.20416021347045898, Loss 0.7588, Prec 87.150%
# best acc: 87.290000
# Epoch 224, Time 16.675, Loss 0.0017, Prec 99.994%
# Validation starts
# Time 0.17711949348449707, Loss 0.7688, Prec 87.030%
# best acc: 87.290000
# Epoch 225, Time 16.992, Loss 0.0018, Prec 99.982%
# Validation starts
# Time 0.17819547653198242, Loss 0.7600, Prec 87.310%
# best acc: 87.310000
# Epoch 226, Time 17.100, Loss 0.0019, Prec 99.964%
# Validation starts
# Time 0.1716306209564209, Loss 0.7590, Prec 87.290%
# best acc: 87.310000
# Epoch 227, Time 17.456, Loss 0.0019, Prec 99.972%
# Validation starts
# Time 0.18217015266418457, Loss 0.7532, Prec 87.080%
# best acc: 87.310000
# Epoch 228, Time 16.989, Loss 0.0019, Prec 99.984%
# Validation starts
# Time 0.17588400840759277, Loss 0.7599, Prec 87.260%
# best acc: 87.310000
# Epoch 229, Time 16.895, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.1773545742034912, Loss 0.7553, Prec 87.300%
# best acc: 87.310000
# Epoch 230, Time 17.284, Loss 0.0019, Prec 99.976%
# Validation starts
# Time 0.20788097381591797, Loss 0.7541, Prec 87.230%
# best acc: 87.310000
# Epoch 231, Time 16.853, Loss 0.0019, Prec 99.966%
# Validation starts
# Time 0.19887590408325195, Loss 0.7522, Prec 87.180%
# best acc: 87.310000
# Epoch 232, Time 17.100, Loss 0.0018, Prec 99.982%
# Validation starts
# Time 0.19218087196350098, Loss 0.7542, Prec 87.110%
# best acc: 87.310000
# Epoch 233, Time 17.457, Loss 0.0016, Prec 99.992%
# Validation starts
# Time 0.19539332389831543, Loss 0.7510, Prec 87.200%
# best acc: 87.310000
# Epoch 234, Time 17.310, Loss 0.0019, Prec 99.980%
# Validation starts
# Time 0.19794535636901855, Loss 0.7610, Prec 87.000%
# best acc: 87.310000
# Epoch 235, Time 17.107, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.23888421058654785, Loss 0.7544, Prec 87.130%
# best acc: 87.310000
# Epoch 236, Time 17.147, Loss 0.0017, Prec 99.988%
# Validation starts
# Time 0.20152521133422852, Loss 0.7522, Prec 87.040%
# best acc: 87.310000
# Epoch 237, Time 16.914, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.19825315475463867, Loss 0.7510, Prec 87.320%
# best acc: 87.320000
# Epoch 238, Time 17.118, Loss 0.0018, Prec 99.986%
# Validation starts
# Time 0.20853400230407715, Loss 0.7568, Prec 87.360%
# best acc: 87.360000
# Epoch 239, Time 16.896, Loss 0.0016, Prec 99.994%
# Validation starts
# Time 0.18103480339050293, Loss 0.7525, Prec 87.280%
# best acc: 87.360000
# Epoch 240, Time 17.003, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.19968628883361816, Loss 0.7523, Prec 87.180%
# best acc: 87.360000
# Epoch 241, Time 16.652, Loss 0.0018, Prec 99.986%
# Validation starts
# Time 0.1737513542175293, Loss 0.7556, Prec 87.220%
# best acc: 87.360000
# Epoch 242, Time 16.745, Loss 0.0017, Prec 99.988%
# Validation starts
# Time 0.21656155586242676, Loss 0.7492, Prec 87.350%
# best acc: 87.360000
# Epoch 243, Time 17.167, Loss 0.0017, Prec 99.978%
# Validation starts
# Time 0.17412424087524414, Loss 0.7501, Prec 87.170%
# best acc: 87.360000
# Epoch 244, Time 16.351, Loss 0.0018, Prec 99.984%
# Validation starts
# Time 0.18684101104736328, Loss 0.7549, Prec 87.290%
# best acc: 87.360000
# Epoch 245, Time 16.508, Loss 0.0018, Prec 99.980%
# Validation starts
# Time 0.1824491024017334, Loss 0.7508, Prec 87.250%
# best acc: 87.360000
# Epoch 246, Time 16.636, Loss 0.0019, Prec 99.978%
# Validation starts
# Time 0.1799156665802002, Loss 0.7555, Prec 87.060%
# best acc: 87.360000
# Epoch 247, Time 16.947, Loss 0.0018, Prec 99.978%
# Validation starts
# Time 0.17669320106506348, Loss 0.7535, Prec 87.310%
# best acc: 87.360000
# Epoch 248, Time 16.788, Loss 0.0017, Prec 99.982%
# Validation starts
# Time 0.21248888969421387, Loss 0.7503, Prec 87.030%
# best acc: 87.360000
# Epoch 249, Time 17.073, Loss 0.0016, Prec 99.984%
# Validation starts
# Time 0.2058544158935547, Loss 0.7515, Prec 87.220%
# best acc: 87.360000
# Epoch 250, Time 17.262, Loss 0.0018, Prec 99.972%
# Validation starts
# Time 0.20752286911010742, Loss 0.7570, Prec 87.250%
# best acc: 87.360000
# Epoch 251, Time 16.676, Loss 0.0016, Prec 99.986%
# Validation starts
# Time 0.20397138595581055, Loss 0.7577, Prec 87.290%
# best acc: 87.360000
# Epoch 252, Time 17.211, Loss 0.0016, Prec 99.986%
# Validation starts
# Time 0.18952131271362305, Loss 0.7554, Prec 87.340%
# best acc: 87.360000
# Epoch 253, Time 16.849, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.2002425193786621, Loss 0.7550, Prec 87.230%
# best acc: 87.360000
# Epoch 254, Time 17.236, Loss 0.0018, Prec 99.984%
# Validation starts
# Time 0.19721269607543945, Loss 0.7599, Prec 87.020%
# best acc: 87.360000
# Epoch 255, Time 16.855, Loss 0.0016, Prec 99.992%
# Validation starts
# Time 0.20430755615234375, Loss 0.7557, Prec 87.130%
# best acc: 87.360000
# Epoch 256, Time 16.805, Loss 0.0017, Prec 99.980%
# Validation starts
# Time 0.198883056640625, Loss 0.7498, Prec 87.250%
# best acc: 87.360000
# Epoch 257, Time 16.896, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.1921536922454834, Loss 0.7546, Prec 87.230%
# best acc: 87.360000
# Epoch 258, Time 17.280, Loss 0.0017, Prec 99.982%
# Validation starts
# Time 0.20784497261047363, Loss 0.7549, Prec 87.200%
# best acc: 87.360000
# Epoch 259, Time 17.023, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.20081305503845215, Loss 0.7529, Prec 87.140%
# best acc: 87.360000
# Epoch 260, Time 17.071, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.1951465606689453, Loss 0.7535, Prec 87.220%
# best acc: 87.360000
# Epoch 261, Time 17.098, Loss 0.0016, Prec 99.990%
# Validation starts
# Time 0.20631957054138184, Loss 0.7588, Prec 87.180%
# best acc: 87.360000
# Epoch 262, Time 16.686, Loss 0.0016, Prec 99.992%
# Validation starts
# Time 0.20058989524841309, Loss 0.7496, Prec 87.260%
# best acc: 87.360000
# Epoch 263, Time 16.576, Loss 0.0014, Prec 99.988%
# Validation starts
# Time 0.19745755195617676, Loss 0.7563, Prec 87.170%
# best acc: 87.360000
# Epoch 264, Time 16.785, Loss 0.0016, Prec 99.980%
# Validation starts
# Time 0.19866132736206055, Loss 0.7557, Prec 87.110%
# best acc: 87.360000
# Epoch 265, Time 16.666, Loss 0.0015, Prec 99.996%
# Validation starts
# Time 0.2025918960571289, Loss 0.7567, Prec 87.260%
# best acc: 87.360000
# Epoch 266, Time 16.563, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.1874990463256836, Loss 0.7536, Prec 87.240%
# best acc: 87.360000
# Epoch 267, Time 16.584, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.19388651847839355, Loss 0.7571, Prec 87.240%
# best acc: 87.360000
# Epoch 268, Time 16.715, Loss 0.0015, Prec 99.982%
# Validation starts
# Time 0.19097900390625, Loss 0.7594, Prec 87.300%
# best acc: 87.360000
# Epoch 269, Time 16.526, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.199066162109375, Loss 0.7624, Prec 87.110%
# best acc: 87.360000
# Epoch 270, Time 16.754, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.19840240478515625, Loss 0.7541, Prec 87.170%
# best acc: 87.360000
# Epoch 271, Time 16.557, Loss 0.0014, Prec 99.994%
# Validation starts
# Time 0.19985485076904297, Loss 0.7555, Prec 87.190%
# best acc: 87.360000
# Epoch 272, Time 16.663, Loss 0.0016, Prec 99.984%
# Validation starts
# Time 0.19817280769348145, Loss 0.7556, Prec 87.150%
# best acc: 87.360000
# Epoch 273, Time 16.860, Loss 0.0018, Prec 99.976%
# Validation starts
# Time 0.19672226905822754, Loss 0.7576, Prec 87.360%
# best acc: 87.360000
# Epoch 274, Time 16.410, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.19251108169555664, Loss 0.7519, Prec 87.180%
# best acc: 87.360000
# Epoch 275, Time 16.611, Loss 0.0017, Prec 99.982%
# Validation starts
# Time 0.19523143768310547, Loss 0.7540, Prec 87.150%
# best acc: 87.360000
# Epoch 276, Time 16.539, Loss 0.0016, Prec 99.984%
# Validation starts
# Time 0.20595836639404297, Loss 0.7557, Prec 87.200%
# best acc: 87.360000
# Epoch 277, Time 16.625, Loss 0.0016, Prec 99.992%
# Validation starts
# Time 0.1979358196258545, Loss 0.7572, Prec 87.200%
# best acc: 87.360000
# Epoch 278, Time 16.755, Loss 0.0015, Prec 99.992%
# Validation starts
# Time 0.2030317783355713, Loss 0.7497, Prec 87.140%
# best acc: 87.360000
# Epoch 279, Time 16.788, Loss 0.0015, Prec 99.982%
# Validation starts
# Time 0.19498205184936523, Loss 0.7535, Prec 87.310%
# best acc: 87.360000
# Epoch 280, Time 16.751, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.20607376098632812, Loss 0.7512, Prec 87.250%
# best acc: 87.360000
# Epoch 281, Time 16.456, Loss 0.0016, Prec 99.980%
# Validation starts
# Time 0.19494390487670898, Loss 0.7500, Prec 87.290%
# best acc: 87.360000
# Epoch 282, Time 16.758, Loss 0.0017, Prec 99.990%
# Validation starts
# Time 0.1935582160949707, Loss 0.7540, Prec 87.130%
# best acc: 87.360000
# Epoch 283, Time 16.531, Loss 0.0017, Prec 99.978%
# Validation starts
# Time 0.1983017921447754, Loss 0.7570, Prec 87.050%
# best acc: 87.360000
# Epoch 284, Time 16.793, Loss 0.0016, Prec 99.982%
# Validation starts
# Time 0.19673442840576172, Loss 0.7593, Prec 87.170%
# best acc: 87.360000
# Epoch 285, Time 17.074, Loss 0.0015, Prec 99.984%
# Validation starts
# Time 0.19887423515319824, Loss 0.7588, Prec 87.190%
# best acc: 87.360000
# Epoch 286, Time 16.639, Loss 0.0014, Prec 99.990%
# Validation starts
# Time 0.19102978706359863, Loss 0.7513, Prec 87.180%
# best acc: 87.360000
# Epoch 287, Time 16.760, Loss 0.0016, Prec 99.988%
# Validation starts
# Time 0.2007591724395752, Loss 0.7536, Prec 87.170%
# best acc: 87.360000
# Epoch 288, Time 16.677, Loss 0.0016, Prec 99.976%
# Validation starts
# Time 0.1896531581878662, Loss 0.7556, Prec 87.170%
# best acc: 87.360000
# Epoch 289, Time 16.689, Loss 0.0016, Prec 99.992%
# Validation starts
# Time 0.19818782806396484, Loss 0.7577, Prec 87.230%
# best acc: 87.360000
# Epoch 290, Time 16.700, Loss 0.0015, Prec 99.980%
# Validation starts
# Time 0.19233059883117676, Loss 0.7547, Prec 87.190%
# best acc: 87.360000
# Epoch 291, Time 16.691, Loss 0.0015, Prec 99.986%
# Validation starts
# Time 0.19772076606750488, Loss 0.7533, Prec 87.110%
# best acc: 87.360000
# Epoch 292, Time 16.698, Loss 0.0014, Prec 99.994%
# Validation starts
# Time 0.20655488967895508, Loss 0.7529, Prec 87.080%
# best acc: 87.360000
# Epoch 293, Time 16.791, Loss 0.0015, Prec 99.990%
# Validation starts
# Time 0.1973581314086914, Loss 0.7524, Prec 87.160%
# best acc: 87.360000
# Epoch 294, Time 16.744, Loss 0.0014, Prec 99.994%
# Validation starts
# Time 0.2013106346130371, Loss 0.7562, Prec 87.190%
# best acc: 87.360000
# Epoch 295, Time 16.562, Loss 0.0015, Prec 99.992%
# Validation starts
# Time 0.19959306716918945, Loss 0.7488, Prec 87.260%
# best acc: 87.360000
# Epoch 296, Time 16.629, Loss 0.0014, Prec 99.990%
# Validation starts
# Time 0.19307327270507812, Loss 0.7503, Prec 87.140%
# best acc: 87.360000
# Epoch 297, Time 16.776, Loss 0.0018, Prec 99.976%
# Validation starts
# Time 0.19609427452087402, Loss 0.7558, Prec 87.190%
# best acc: 87.360000
# Epoch 298, Time 16.798, Loss 0.0014, Prec 99.988%
# Validation starts
# Time 0.19928312301635742, Loss 0.7573, Prec 87.190%
# best acc: 87.360000
# Epoch 299, Time 16.723, Loss 0.0016, Prec 99.990%
# Validation starts
# Time 0.20469212532043457, Loss 0.7555, Prec 87.200%
# best acc: 87.360000
# Sequential(
#   (0): QuantConv2df(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (2): ReLU()
#   (3): QuantConv2df(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (5): ReLU()
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): QuantConv2df(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (9): ReLU()
#   (10): QuantConv2df(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (12): ReLU()
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (14): QuantConv2df(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (16): ReLU()
#   (17): QuantConv2df(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (19): ReLU()
#   (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (21): QuantConv2df(512, 1024, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (22): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#   (23): ReLU()
#   (24): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Sequential(
#   (0): Linear(in_features=1024, out_features=10, bias=True)
# )
# Epoch 0, Time 16.615, Loss 2.3333, Prec 28.946%
# Validation starts
# Time 0.1976146697998047, Loss 1.5770, Prec 42.910%
# best acc: 42.910000
# Epoch 1, Time 16.601, Loss 1.5189, Prec 45.714%
# Validation starts
# Time 0.20357656478881836, Loss 1.3012, Prec 53.710%
# best acc: 53.710000
# Epoch 2, Time 16.940, Loss 1.2283, Prec 56.252%
# Validation starts
# Time 0.19872403144836426, Loss 1.1544, Prec 59.590%
# best acc: 59.590000
# Epoch 3, Time 16.900, Loss 1.0480, Prec 62.878%
# Validation starts
# Time 0.20430469512939453, Loss 1.1374, Prec 60.410%
# best acc: 60.410000
# Epoch 4, Time 16.923, Loss 0.8867, Prec 68.928%
# Validation starts
# Time 0.20656728744506836, Loss 0.8651, Prec 69.400%
# best acc: 69.400000
# Epoch 5, Time 16.943, Loss 0.7841, Prec 72.752%
# Validation starts
# Time 0.2054431438446045, Loss 0.7752, Prec 72.970%
# best acc: 72.970000
# Epoch 6, Time 16.997, Loss 0.7101, Prec 75.330%
# Validation starts
# Time 0.19860100746154785, Loss 0.6787, Prec 76.400%
# best acc: 76.400000
# Epoch 7, Time 17.047, Loss 0.6460, Prec 77.530%
# Validation starts
# Time 0.19956278800964355, Loss 0.7055, Prec 75.480%
# best acc: 76.400000
# Epoch 8, Time 16.888, Loss 0.5917, Prec 79.592%
# Validation starts
# Time 0.2071211338043213, Loss 0.6421, Prec 77.900%
# best acc: 77.900000
# Epoch 9, Time 16.799, Loss 0.5488, Prec 80.952%
# Validation starts
# Time 0.19985532760620117, Loss 0.6358, Prec 79.640%
# best acc: 79.640000
# Epoch 10, Time 17.031, Loss 0.5208, Prec 82.232%
# Validation starts
# Time 0.19292163848876953, Loss 0.5991, Prec 79.760%
# best acc: 79.760000
# Epoch 11, Time 17.047, Loss 0.4868, Prec 83.140%
# Validation starts
# Time 0.20726776123046875, Loss 0.6239, Prec 79.410%
# best acc: 79.760000
# Epoch 12, Time 17.042, Loss 0.4604, Prec 84.206%
# Validation starts
# Time 0.20572853088378906, Loss 0.6204, Prec 79.350%
# best acc: 79.760000
# Epoch 13, Time 17.015, Loss 0.4323, Prec 85.052%
# Validation starts
# Time 0.20046138763427734, Loss 0.5411, Prec 82.090%
# best acc: 82.090000
# Epoch 14, Time 16.700, Loss 0.4111, Prec 85.922%
# Validation starts
# Time 0.21657562255859375, Loss 0.6184, Prec 80.470%
# best acc: 82.090000
# Epoch 15, Time 16.929, Loss 0.3921, Prec 86.422%
# Validation starts
# Time 0.20092463493347168, Loss 0.6599, Prec 80.340%
# best acc: 82.090000
# Epoch 16, Time 16.938, Loss 0.3785, Prec 86.898%
# Validation starts
# Time 0.20003318786621094, Loss 0.5550, Prec 82.410%
# best acc: 82.410000
# Epoch 17, Time 16.999, Loss 0.3588, Prec 87.678%
# Validation starts
# Time 0.19064617156982422, Loss 0.5344, Prec 83.060%
# best acc: 83.060000
# Epoch 18, Time 17.101, Loss 0.3369, Prec 88.328%
# Validation starts
# Time 0.20870518684387207, Loss 0.5139, Prec 83.930%
# best acc: 83.930000
# ...
# best acc: 90.170000
# Epoch 186, Time 29.518, Loss 0.0028, Prec 99.952%
# Validation starts
# Time 0.20850872993469238, Loss 0.5370, Prec 89.830%
# best acc: 90.170000
# Epoch 187, Time 30.008, Loss 0.0027, Prec 99.964%
# Validation starts
# Time 0.18584084510803223, Loss 0.5310, Prec 90.030%
# best acc: 90.170000
# Epoch 188, Time 29.821, Loss 0.0025, Prec 99.958%
# Validation starts
# Time 0.2024843692779541, Loss 0.5338, Prec 90.030%
# best acc: 90.170000
# Epoch 189, Time 29.976, Loss 0.0027, Prec 99.956%
# Validation starts
# Time 0.18895530700683594, Loss 0.5375, Prec 90.130%
# best acc: 90.170000
# Epoch 190, Time 29.662, Loss 0.0029, Prec 99.956%
# Validation starts
# Time 0.20419716835021973, Loss 0.5384, Prec 89.860%
# best acc: 90.170000
# Epoch 191, Time 30.091, Loss 0.0029, Prec 99.950%
# Validation starts
# Time 0.20511221885681152, Loss 0.5392, Prec 89.890%
# best acc: 90.170000
# Epoch 192, Time 29.456, Loss 0.0026, Prec 99.958%
# Validation starts
# Time 0.20444822311401367, Loss 0.5420, Prec 89.800%
# best acc: 90.170000
# Epoch 193, Time 29.730, Loss 0.0026, Prec 99.956%
# Validation starts
# Time 0.20013141632080078, Loss 0.5418, Prec 89.930%
# best acc: 90.170000
# Epoch 194, Time 29.327, Loss 0.0026, Prec 99.964%
# Validation starts
# Time 0.2006216049194336, Loss 0.5464, Prec 89.890%
# best acc: 90.170000
# Epoch 195, Time 29.731, Loss 0.0022, Prec 99.974%
# Validation starts
# Time 0.20598077774047852, Loss 0.5377, Prec 89.890%
# best acc: 90.170000
# Epoch 196, Time 29.739, Loss 0.0025, Prec 99.962%
# Validation starts
# Time 0.1987900733947754, Loss 0.5452, Prec 89.840%
# best acc: 90.170000
# Epoch 197, Time 29.869, Loss 0.0024, Prec 99.962%
# Validation starts
# Time 0.21993041038513184, Loss 0.5491, Prec 89.940%
# best acc: 90.170000
# Epoch 198, Time 29.804, Loss 0.0026, Prec 99.946%
# Validation starts
# Time 0.20312738418579102, Loss 0.5470, Prec 89.810%
# best acc: 90.170000
# Epoch 199, Time 29.846, Loss 0.0024, Prec 99.960%
# Validation starts
# Time 0.19971466064453125, Loss 0.5457, Prec 89.860%
# best acc: 90.170000
# Epoch 200, Time 29.768, Loss 0.0022, Prec 99.976%
# Validation starts
# Time 0.2051546573638916, Loss 0.5406, Prec 89.920%
# best acc: 90.170000
# Epoch 201, Time 29.216, Loss 0.0022, Prec 99.970%
# Validation starts
# Time 0.203596830368042, Loss 0.5434, Prec 89.900%
# best acc: 90.170000
# Epoch 202, Time 29.847, Loss 0.0022, Prec 99.970%
# Validation starts
# Time 0.20693016052246094, Loss 0.5431, Prec 89.910%
# best acc: 90.170000
# Epoch 203, Time 29.782, Loss 0.0022, Prec 99.972%
# Validation starts
# Time 0.2043931484222412, Loss 0.5427, Prec 89.820%
# best acc: 90.170000
# Epoch 204, Time 29.691, Loss 0.0018, Prec 99.980%
# Validation starts
# Time 0.19957280158996582, Loss 0.5379, Prec 89.940%
# best acc: 90.170000
# Epoch 205, Time 29.590, Loss 0.0021, Prec 99.984%
# Validation starts
# Time 0.20563435554504395, Loss 0.5339, Prec 90.060%
# best acc: 90.170000
# Epoch 206, Time 29.316, Loss 0.0019, Prec 99.980%
# Validation starts
# Time 0.20381402969360352, Loss 0.5440, Prec 89.910%
# best acc: 90.170000
# Epoch 207, Time 29.825, Loss 0.0019, Prec 99.974%
# Validation starts
# Time 0.18594145774841309, Loss 0.5456, Prec 90.140%
# best acc: 90.170000
# Epoch 208, Time 29.506, Loss 0.0022, Prec 99.962%
# Validation starts
# Time 0.20604896545410156, Loss 0.5482, Prec 89.950%
# best acc: 90.170000
# Epoch 209, Time 29.736, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.1994328498840332, Loss 0.5449, Prec 90.090%
# best acc: 90.170000
# Epoch 210, Time 29.781, Loss 0.0017, Prec 99.984%
# Validation starts
# Time 0.2013237476348877, Loss 0.5437, Prec 89.960%
# best acc: 90.170000
# Epoch 211, Time 29.472, Loss 0.0018, Prec 99.974%
# Validation starts
# Time 0.20198464393615723, Loss 0.5394, Prec 90.020%
# best acc: 90.170000
# Epoch 212, Time 29.501, Loss 0.0020, Prec 99.976%
# Validation starts
# Time 0.20117855072021484, Loss 0.5413, Prec 90.200%
# best acc: 90.200000
# Epoch 213, Time 29.339, Loss 0.0018, Prec 99.976%
# Validation starts
# Time 0.2014753818511963, Loss 0.5455, Prec 89.980%
# best acc: 90.200000
# Epoch 214, Time 29.688, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.19836044311523438, Loss 0.5454, Prec 89.950%
# best acc: 90.200000
# Epoch 215, Time 29.705, Loss 0.0018, Prec 99.972%
# Validation starts
# Time 0.2021322250366211, Loss 0.5534, Prec 89.900%
# best acc: 90.200000
# Epoch 216, Time 29.744, Loss 0.0019, Prec 99.966%
# Validation starts
# Time 0.20661377906799316, Loss 0.5438, Prec 90.090%
# best acc: 90.200000
# Epoch 217, Time 29.415, Loss 0.0016, Prec 99.986%
# Validation starts
# Time 0.20819687843322754, Loss 0.5463, Prec 90.190%
# best acc: 90.200000
# Epoch 218, Time 29.155, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.20836234092712402, Loss 0.5479, Prec 90.010%
# best acc: 90.200000
# Epoch 219, Time 29.396, Loss 0.0017, Prec 99.986%
# Validation starts
# Time 0.20286822319030762, Loss 0.5539, Prec 90.060%
# best acc: 90.200000
# Epoch 220, Time 29.963, Loss 0.0016, Prec 99.978%
# Validation starts
# Time 0.20493555068969727, Loss 0.5508, Prec 90.010%
# best acc: 90.200000
# Epoch 221, Time 29.554, Loss 0.0015, Prec 99.984%
# Validation starts
# Time 0.2012195587158203, Loss 0.5538, Prec 90.120%
# best acc: 90.200000
# Epoch 222, Time 29.286, Loss 0.0018, Prec 99.978%
# Validation starts
# Time 0.20228171348571777, Loss 0.5504, Prec 90.100%
# best acc: 90.200000
# Epoch 223, Time 28.989, Loss 0.0015, Prec 99.988%
# Validation starts
# Time 0.20067930221557617, Loss 0.5507, Prec 90.200%
# best acc: 90.200000
# Epoch 224, Time 29.953, Loss 0.0014, Prec 99.984%
# Validation starts
# Time 0.20494747161865234, Loss 0.5529, Prec 90.190%
# best acc: 90.200000
# Epoch 225, Time 29.687, Loss 0.0015, Prec 99.984%
# Validation starts
# Time 0.22434592247009277, Loss 0.5471, Prec 90.190%
# best acc: 90.200000
# Epoch 226, Time 30.011, Loss 0.0015, Prec 99.984%
# Validation starts
# Time 0.21123170852661133, Loss 0.5527, Prec 90.100%
# best acc: 90.200000
# Epoch 227, Time 29.926, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.20461416244506836, Loss 0.5502, Prec 90.200%
# best acc: 90.200000
# Epoch 228, Time 29.487, Loss 0.0015, Prec 99.986%
# Validation starts
# Time 0.21082353591918945, Loss 0.5492, Prec 90.210%
# best acc: 90.210000
# Epoch 229, Time 29.597, Loss 0.0014, Prec 99.990%
# Validation starts
# Time 0.20444679260253906, Loss 0.5493, Prec 90.170%
# best acc: 90.210000
# Epoch 230, Time 29.473, Loss 0.0016, Prec 99.976%
# Validation starts
# Time 0.21468567848205566, Loss 0.5489, Prec 90.200%
# best acc: 90.210000
# Epoch 231, Time 29.887, Loss 0.0013, Prec 99.990%
# Validation starts
# Time 0.19996023178100586, Loss 0.5482, Prec 90.240%
# best acc: 90.240000
# Epoch 232, Time 29.712, Loss 0.0014, Prec 99.986%
# Validation starts
# Time 0.2005164623260498, Loss 0.5508, Prec 90.110%
# best acc: 90.240000
# Epoch 233, Time 29.727, Loss 0.0015, Prec 99.982%
# Validation starts
# Time 0.1994309425354004, Loss 0.5498, Prec 90.260%
# best acc: 90.260000
# Epoch 234, Time 29.435, Loss 0.0014, Prec 99.978%
# Validation starts
# Time 0.20172953605651855, Loss 0.5511, Prec 90.190%
# best acc: 90.260000
# Epoch 235, Time 29.686, Loss 0.0015, Prec 99.978%
# Validation starts
# Time 0.19835853576660156, Loss 0.5499, Prec 90.140%
# best acc: 90.260000
# Epoch 236, Time 28.982, Loss 0.0014, Prec 99.980%
# Validation starts
# Time 0.19103240966796875, Loss 0.5498, Prec 90.100%
# best acc: 90.260000
# Epoch 237, Time 29.704, Loss 0.0014, Prec 99.982%
# Validation starts
# Time 0.20023655891418457, Loss 0.5492, Prec 90.290%
# best acc: 90.290000
# Epoch 238, Time 29.821, Loss 0.0013, Prec 99.988%
# Validation starts
# Time 0.20090794563293457, Loss 0.5509, Prec 90.090%
# best acc: 90.290000
# Epoch 239, Time 28.029, Loss 0.0015, Prec 99.992%
# Validation starts
# Time 0.20309114456176758, Loss 0.5478, Prec 90.190%
# best acc: 90.290000
# Epoch 240, Time 29.991, Loss 0.0014, Prec 99.976%
# Validation starts
# Time 0.20358753204345703, Loss 0.5508, Prec 90.160%
# best acc: 90.290000
# Epoch 241, Time 30.113, Loss 0.0013, Prec 99.992%
# Validation starts
# Time 0.19457268714904785, Loss 0.5497, Prec 90.210%
# best acc: 90.290000
# Epoch 242, Time 30.065, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.215501070022583, Loss 0.5504, Prec 90.140%
# best acc: 90.290000
# Epoch 243, Time 30.124, Loss 0.0014, Prec 99.994%
# Validation starts
# Time 0.20213842391967773, Loss 0.5527, Prec 90.130%
# best acc: 90.290000
# Epoch 244, Time 30.125, Loss 0.0013, Prec 99.990%
# Validation starts
# Time 0.20013809204101562, Loss 0.5475, Prec 90.320%
# best acc: 90.320000
# Epoch 245, Time 30.391, Loss 0.0013, Prec 99.992%
# Validation starts
# Time 0.20006561279296875, Loss 0.5484, Prec 90.340%
# best acc: 90.340000
# Epoch 246, Time 30.459, Loss 0.0013, Prec 99.996%
# Validation starts
# Time 0.1914231777191162, Loss 0.5493, Prec 90.290%
# best acc: 90.340000
# Epoch 247, Time 30.337, Loss 0.0013, Prec 99.992%
# Validation starts
# Time 0.20274043083190918, Loss 0.5475, Prec 90.140%
# best acc: 90.340000
# Epoch 248, Time 30.119, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.19428062438964844, Loss 0.5486, Prec 90.170%
# best acc: 90.340000
# Epoch 249, Time 30.279, Loss 0.0013, Prec 99.988%
# Validation starts
# Time 0.19792389869689941, Loss 0.5485, Prec 90.090%
# best acc: 90.340000
# Epoch 250, Time 30.359, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.19767332077026367, Loss 0.5505, Prec 90.250%
# best acc: 90.340000
# Epoch 251, Time 30.283, Loss 0.0013, Prec 99.988%
# Validation starts
# Time 0.2044086456298828, Loss 0.5480, Prec 90.210%
# best acc: 90.340000
# Epoch 252, Time 30.310, Loss 0.0011, Prec 99.992%
# Validation starts
# Time 0.20306801795959473, Loss 0.5489, Prec 90.310%
# best acc: 90.340000
# Epoch 253, Time 30.253, Loss 0.0012, Prec 99.998%
# Validation starts
# Time 0.18427062034606934, Loss 0.5483, Prec 90.220%
# best acc: 90.340000
# Epoch 254, Time 30.295, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.20789766311645508, Loss 0.5504, Prec 90.290%
# best acc: 90.340000
# Epoch 255, Time 29.931, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.20646929740905762, Loss 0.5498, Prec 90.170%
# best acc: 90.340000
# Epoch 256, Time 27.299, Loss 0.0012, Prec 99.996%
# Validation starts
# Time 0.20328116416931152, Loss 0.5493, Prec 90.120%
# best acc: 90.340000
# Epoch 257, Time 29.994, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.20171165466308594, Loss 0.5487, Prec 90.290%
# best acc: 90.340000
# Epoch 258, Time 30.058, Loss 0.0013, Prec 99.992%
# Validation starts
# Time 0.1988832950592041, Loss 0.5482, Prec 90.160%
# best acc: 90.340000
# Epoch 259, Time 29.993, Loss 0.0014, Prec 99.986%
# Validation starts
# Time 0.2005314826965332, Loss 0.5481, Prec 90.270%
# best acc: 90.340000
# Epoch 260, Time 29.612, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.19835591316223145, Loss 0.5506, Prec 90.210%
# best acc: 90.340000
# Epoch 261, Time 29.668, Loss 0.0013, Prec 99.986%
# Validation starts
# Time 0.20085549354553223, Loss 0.5505, Prec 90.170%
# best acc: 90.340000
# Epoch 262, Time 30.117, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.20051860809326172, Loss 0.5482, Prec 90.150%
# best acc: 90.340000
# Epoch 263, Time 29.650, Loss 0.0011, Prec 99.994%
# Validation starts
# Time 0.19783258438110352, Loss 0.5496, Prec 90.140%
# best acc: 90.340000
# Epoch 264, Time 28.410, Loss 0.0011, Prec 99.994%
# Validation starts
# Time 0.20819902420043945, Loss 0.5520, Prec 90.130%
# best acc: 90.340000
# Epoch 265, Time 29.912, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.2059004306793213, Loss 0.5493, Prec 90.130%
# best acc: 90.340000
# Epoch 266, Time 30.012, Loss 0.0012, Prec 99.996%
# Validation starts
# Time 0.20372605323791504, Loss 0.5522, Prec 90.190%
# best acc: 90.340000
# Epoch 267, Time 30.040, Loss 0.0013, Prec 99.990%
# Validation starts
# Time 0.2053382396697998, Loss 0.5526, Prec 90.090%
# best acc: 90.340000
# Epoch 268, Time 29.591, Loss 0.0011, Prec 99.988%
# Validation starts
# Time 0.20255684852600098, Loss 0.5513, Prec 90.250%
# best acc: 90.340000
# Epoch 269, Time 30.061, Loss 0.0014, Prec 99.984%
# Validation starts
# Time 0.198714017868042, Loss 0.5516, Prec 90.270%
# best acc: 90.340000
# Epoch 270, Time 30.094, Loss 0.0012, Prec 99.986%
# Validation starts
# Time 0.20168399810791016, Loss 0.5482, Prec 90.320%
# best acc: 90.340000
# Epoch 271, Time 30.021, Loss 0.0012, Prec 99.992%
# Validation starts
# Time 0.20702147483825684, Loss 0.5497, Prec 90.160%
# best acc: 90.340000
# Epoch 272, Time 29.782, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.19825053215026855, Loss 0.5487, Prec 90.140%
# best acc: 90.340000
# Epoch 273, Time 29.977, Loss 0.0012, Prec 99.988%
# Validation starts
# Time 0.1985924243927002, Loss 0.5494, Prec 90.230%
# best acc: 90.340000
# Epoch 274, Time 29.637, Loss 0.0012, Prec 99.988%
# Validation starts
# Time 0.19476962089538574, Loss 0.5476, Prec 90.230%
# best acc: 90.340000
# Epoch 275, Time 29.484, Loss 0.0012, Prec 99.986%
# Validation starts
# Time 0.1992800235748291, Loss 0.5461, Prec 90.030%
# best acc: 90.340000
# Epoch 276, Time 29.755, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.19255447387695312, Loss 0.5484, Prec 90.220%
# best acc: 90.340000
# Epoch 277, Time 29.984, Loss 0.0013, Prec 99.994%
# Validation starts
# Time 0.20577669143676758, Loss 0.5492, Prec 90.080%
# best acc: 90.340000
# Epoch 278, Time 30.080, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.20086383819580078, Loss 0.5498, Prec 90.190%
# best acc: 90.340000
# Epoch 279, Time 30.162, Loss 0.0013, Prec 99.982%
# Validation starts
# Time 0.19884777069091797, Loss 0.5501, Prec 90.140%
# best acc: 90.340000
# Epoch 280, Time 29.892, Loss 0.0011, Prec 99.994%
# Validation starts
# Time 0.21160531044006348, Loss 0.5515, Prec 90.190%
# best acc: 90.340000
# Epoch 281, Time 29.356, Loss 0.0011, Prec 99.992%
# Validation starts
# Time 0.20746898651123047, Loss 0.5504, Prec 90.140%
# best acc: 90.340000
# Epoch 282, Time 29.374, Loss 0.0013, Prec 99.986%
# Validation starts
# Time 0.20570635795593262, Loss 0.5484, Prec 90.230%
# best acc: 90.340000
# Epoch 283, Time 29.408, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.20191454887390137, Loss 0.5521, Prec 90.140%
# best acc: 90.340000
# Epoch 284, Time 30.021, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.2400197982788086, Loss 0.5494, Prec 90.250%
# best acc: 90.340000
# Epoch 285, Time 29.479, Loss 0.0011, Prec 99.994%
# Validation starts
# Time 0.21224260330200195, Loss 0.5495, Prec 90.220%
# best acc: 90.340000
# Epoch 286, Time 29.967, Loss 0.0012, Prec 99.986%
# Validation starts
# Time 0.2001955509185791, Loss 0.5524, Prec 90.150%
# best acc: 90.340000
# Epoch 287, Time 30.146, Loss 0.0011, Prec 99.988%
# Validation starts
# Time 0.21308135986328125, Loss 0.5494, Prec 90.140%
# best acc: 90.340000
# Epoch 288, Time 30.009, Loss 0.0013, Prec 99.982%
# Validation starts
# Time 0.21106958389282227, Loss 0.5526, Prec 90.240%
# best acc: 90.340000
# Epoch 289, Time 29.956, Loss 0.0013, Prec 99.990%
# Validation starts
# Time 0.20234155654907227, Loss 0.5490, Prec 90.250%
# best acc: 90.340000
# Epoch 290, Time 30.204, Loss 0.0012, Prec 99.996%
# Validation starts
# Time 0.19410276412963867, Loss 0.5517, Prec 90.190%
# best acc: 90.340000
# Epoch 291, Time 29.532, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.20507049560546875, Loss 0.5525, Prec 90.090%
# best acc: 90.340000
# Epoch 292, Time 29.876, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.20314741134643555, Loss 0.5513, Prec 90.160%
# best acc: 90.340000
# Epoch 293, Time 29.594, Loss 0.0012, Prec 99.990%
# Validation starts
# Time 0.18309283256530762, Loss 0.5502, Prec 90.080%
# best acc: 90.340000
# Epoch 294, Time 29.639, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.19803905487060547, Loss 0.5514, Prec 90.120%
# best acc: 90.340000
# Epoch 295, Time 29.707, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.2054746150970459, Loss 0.5504, Prec 90.100%
# best acc: 90.340000
# Epoch 296, Time 29.625, Loss 0.0011, Prec 99.992%
# Validation starts
# Time 0.2047562599182129, Loss 0.5486, Prec 90.090%
# best acc: 90.340000
# Epoch 297, Time 29.918, Loss 0.0011, Prec 100.000%
# Validation starts
# Time 0.1977231502532959, Loss 0.5490, Prec 90.160%
# best acc: 90.340000
# Epoch 298, Time 29.849, Loss 0.0012, Prec 99.994%
# Validation starts
# Time 0.24094104766845703, Loss 0.5488, Prec 90.100%
# best acc: 90.340000
# Epoch 299, Time 30.132, Loss 0.0011, Prec 99.998%
# Validation starts
# Time 0.20491433143615723, Loss 0.5488, Prec 90.120%
# best acc: 90.340000

# %%
dump_vars('Reference_result.txt', result=result, prec=prec)

# %%
{k: max(prec[k]) for k in prec}
# Out:
# {'R32_LU_4X': 87.36,
#  'R16_LU_4X': 91.74,
#  'R16_CE_4X': 87.83,
#  'R32_LU_2X': 92.09,
#  'R16_LU_2X': 92.94,
#  'R16_CE_2X': 91.57,
#  'R32_LU_0X': 91.7,
#  'R16_LU_0X': 92.82,
#  'R16_CE_0X': 90.34}
